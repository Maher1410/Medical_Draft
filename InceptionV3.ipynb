# %% [markdown]
# DEEP LEARNING PROJECT
#
# PROBLEM STATEMENT: AI diagnostics in bone oncology for predicting bone metastasis in lung cancer patients

# %% [markdown]
# 1. S SWARATHMICA - 125156119
# 2. PARITOSH SRIVASTAVA- 125156083
# 3. GOPIDI PRANAY - 125156086
# 4. KARTHIK NARAYAN MOHAN - 125156054

# %%
import tensorflow as tf
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# Load InceptionV3 with input size (299, 299)
base_model = InceptionV3(
    weights='imagenet',
    include_top=False,
    input_shape=(299, 299, 3)  # Update input shape
)

# Freeze layers
for layer in base_model.layers:
    layer.trainable = False

# %%
# Modify the final output layer to match the number of classes 
x = base_model.output
x = Flatten()(x)
x = Dense(1024, activation='relu')(x)
x = Dropout(0.5)(x)
x = Dense(512, activation='relu')(x)
x = Dropout(0.5)(x)
predictions = Dense(3, activation='softmax')(x)  # Use 'softmax' for multi-class classification

# Create the model
model = Model(inputs=base_model.input, outputs=predictions)

# Compile the model for multi-class classification
model.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
import os
import shutil
from sklearn.model_selection import train_test_split

# Define your dataset directory and target directories for split
train_dir = r"C:\Users\DELL 5540\Desktop\AI-Diagnostics-for-Predicting-Bone-Metastasis-in-Lung-Cancer-Patients-main\archive\The IQ-OTHNCCD lung cancer dataset\The IQ-OTHNCCD lung cancer dataset\train"
val_dir = r"C:\Users\DELL 5540\Desktop\AI-Diagnostics-for-Predicting-Bone-Metastasis-in-Lung-Cancer-Patients-main\archive\The IQ-OTHNCCD lung cancer dataset\The IQ-OTHNCCD lung cancer dataset\val"
test_dir = r"C:\Users\DELL 5540\Desktop\AI-Diagnostics-for-Predicting-Bone-Metastasis-in-Lung-Cancer-Patients-main\archive\The IQ-OTHNCCD lung cancer dataset\The IQ-OTHNCCD lung cancer dataset\test"

# %%
from tensorflow.keras.applications.inception_v3 import InceptionV3, preprocess_input

img_height, img_width = 299, 299  # InceptionV3 requires 299x299 inputs

# Updated Data Generators with InceptionV3 preprocessing
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,  # Instead of rescale
    rotation_range=40,
    width_shift_range=0.3,
    height_shift_range=0.3,
    shear_range=0.2,
    zoom_range=0.3,
    brightness_range=[0.8, 1.2],
    horizontal_flip=True,
    fill_mode='nearest'
)

val_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

# Generators remain the same (already using 299x299)
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_height, img_width),
    batch_size=32,
    class_mode='categorical'
)

val_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=(img_height, img_width),
    batch_size=32,
    class_mode='categorical'
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(img_height, img_width),
    batch_size=32,
    class_mode='categorical'
)
# Out:
# Found 767 images belonging to 3 classes.
# Found 164 images belonging to 3 classes.
# Found 166 images belonging to 3 classes.

# %%
from tensorflow.keras.callbacks import EarlyStopping

# Define EarlyStopping callback
early_stopping = EarlyStopping(monitor='accuracy', patience=10, restore_best_weights=True)

# Fit the model with early stopping
history = model.fit(
    train_generator,
    epochs=200,  # Adjust as needed
    steps_per_epoch=train_generator.samples // train_generator.batch_size,
    validation_data=val_generator,
    validation_steps=val_generator.samples // val_generator.batch_size,
      # Add the callback here
)
# Out:
# C:\Users\DELL 5540\AppData\Roaming\Python\Python311\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 104s 4s/step - accuracy: 0.5364 - loss: 4.3213 - val_accuracy: 0.7688 - val_loss: 1.0689
# Epoch 2/200
#  1/23 ━━━━━━━━━━━━━━━━━━━━ 1:16 3s/step - accuracy: 0.6250 - loss: 3.4148
# C:\Users\DELL 5540\AppData\Roaming\Python\Python311\site-packages\keras\src\trainers\epoch_iterator.py:107: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 13s 427ms/step - accuracy: 0.6250 - loss: 3.4148 - val_accuracy: 0.7563 - val_loss: 1.0290
# Epoch 3/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 93s 4s/step - accuracy: 0.6395 - loss: 3.3811 - val_accuracy: 0.8375 - val_loss: 1.2409
# Epoch 4/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 13s 426ms/step - accuracy: 0.8710 - loss: 1.1997 - val_accuracy: 0.8438 - val_loss: 1.2177
# Epoch 5/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 95s 4s/step - accuracy: 0.7315 - loss: 2.3238 - val_accuracy: 0.7437 - val_loss: 1.5470
# Epoch 6/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 13s 434ms/step - accuracy: 0.7812 - loss: 1.4813 - val_accuracy: 0.7500 - val_loss: 1.5201
# Epoch 7/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 94s 4s/step - accuracy: 0.7251 - loss: 1.9731 - val_accuracy: 0.8813 - val_loss: 0.6672
# Epoch 8/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 13s 428ms/step - accuracy: 0.7500 - loss: 1.6617 - val_accuracy: 0.8875 - val_loss: 0.6534
# Epoch 9/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - accuracy: 0.7338 - loss: 1.4932 - val_accuracy: 0.8375 - val_loss: 0.5033
# Epoch 10/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 12s 406ms/step - accuracy: 0.7812 - loss: 1.3943 - val_accuracy: 0.8313 - val_loss: 0.4901
# Epoch 11/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 91s 4s/step - accuracy: 0.7543 - loss: 1.2479 - val_accuracy: 0.7875 - val_loss: 0.4903
# Epoch 12/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 13s 419ms/step - accuracy: 0.8438 - loss: 0.7758 - val_accuracy: 0.8250 - val_loss: 0.4460
# Epoch 13/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 86s 4s/step - accuracy: 0.7952 - loss: 0.7831 - val_accuracy: 0.7688 - val_loss: 0.4581
# Epoch 14/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 12s 401ms/step - accuracy: 0.6875 - loss: 0.9008 - val_accuracy: 0.7750 - val_loss: 0.4625
# Epoch 15/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 86s 4s/step - accuracy: 0.7785 - loss: 0.7874 - val_accuracy: 0.8313 - val_loss: 0.3654
# Epoch 16/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 12s 398ms/step - accuracy: 0.7812 - loss: 0.6354 - val_accuracy: 0.8375 - val_loss: 0.3634
# Epoch 17/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - accuracy: 0.7421 - loss: 0.7577 - val_accuracy: 0.8188 - val_loss: 0.3750
# Epoch 18/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 12s 409ms/step - accuracy: 0.8125 - loss: 0.9918 - val_accuracy: 0.8000 - val_loss: 0.3890
# Epoch 19/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 86s 4s/step - accuracy: 0.7953 - loss: 0.5670 - val_accuracy: 0.8313 - val_loss: 0.3941
# Epoch 20/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 12s 404ms/step - accuracy: 0.6250 - loss: 0.7220 - val_accuracy: 0.8313 - val_loss: 0.3829
# Epoch 21/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - accuracy: 0.7527 - loss: 0.6605 - val_accuracy: 0.8313 - val_loss: 0.4266
# Epoch 22/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 12s 407ms/step - accuracy: 0.6562 - loss: 1.1568 - val_accuracy: 0.7875 - val_loss: 0.4598
# Epoch 23/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - accuracy: 0.7762 - loss: 0.6209 - val_accuracy: 0.8313 - val_loss: 0.4047
# Epoch 24/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 12s 410ms/step - accuracy: 0.8438 - loss: 0.4648 - val_accuracy: 0.8313 - val_loss: 0.3997
# Epoch 25/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 98s 4s/step - accuracy: 0.8084 - loss: 0.5137 - val_accuracy: 0.8313 - val_loss: 0.4121
# Epoch 26/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 13s 443ms/step - accuracy: 0.8750 - loss: 0.3826 - val_accuracy: 0.8313 - val_loss: 0.4066
# Epoch 27/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 96s 4s/step - accuracy: 0.8074 - loss: 0.4940 - val_accuracy: 0.8125 - val_loss: 0.4506
# Epoch 28/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 13s 445ms/step - accuracy: 0.8750 - loss: 0.2765 - val_accuracy: 0.8062 - val_loss: 0.4724
# Epoch 29/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 98s 4s/step - accuracy: 0.8137 - loss: 0.4837 - val_accuracy: 0.8313 - val_loss: 0.4091
# Epoch 30/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 14s 463ms/step - accuracy: 0.7500 - loss: 0.6201 - val_accuracy: 0.8313 - val_loss: 0.4012
# Epoch 31/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 97s 4s/step - accuracy: 0.8124 - loss: 0.5075 - val_accuracy: 0.8375 - val_loss: 0.4330
# Epoch 32/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 13s 442ms/step - accuracy: 0.8750 - loss: 0.4069 - val_accuracy: 0.8125 - val_loss: 0.4450
# Epoch 33/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 96s 4s/step - accuracy: 0.8236 - loss: 0.4897 - val_accuracy: 0.8375 - val_loss: 0.3756
# Epoch 34/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 14s 454ms/step - accuracy: 0.8125 - loss: 0.6660 - val_accuracy: 0.8375 - val_loss: 0.3712
# Epoch 35/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 97s 4s/step - accuracy: 0.7919 - loss: 0.5654 - val_accuracy: 0.8250 - val_loss: 0.4341
# Epoch 36/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 14s 468ms/step - accuracy: 0.8750 - loss: 0.4368 - val_accuracy: 0.8250 - val_loss: 0.4312
# Epoch 37/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 98s 4s/step - accuracy: 0.8179 - loss: 0.5058 - val_accuracy: 0.8313 - val_loss: 0.4376
# Epoch 38/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 14s 463ms/step - accuracy: 0.8438 - loss: 0.4068 - val_accuracy: 0.8188 - val_loss: 0.4473
# Epoch 39/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 97s 4s/step - accuracy: 0.8135 - loss: 0.4871 - val_accuracy: 0.8500 - val_loss: 0.3598
# Epoch 40/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 14s 456ms/step - accuracy: 0.8125 - loss: 0.4692 - val_accuracy: 0.8562 - val_loss: 0.3581
# Epoch 41/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 97s 4s/step - accuracy: 0.8307 - loss: 0.4347 - val_accuracy: 0.8500 - val_loss: 0.3781
# Epoch 42/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 13s 442ms/step - accuracy: 0.8750 - loss: 0.3970 - val_accuracy: 0.8438 - val_loss: 0.3821
# Epoch 43/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 97s 4s/step - accuracy: 0.8549 - loss: 0.3993 - val_accuracy: 0.8250 - val_loss: 0.4237
# Epoch 44/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 14s 448ms/step - accuracy: 0.7812 - loss: 0.4970 - val_accuracy: 0.8188 - val_loss: 0.4304
# Epoch 45/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 97s 4s/step - accuracy: 0.8334 - loss: 0.4490 - val_accuracy: 0.8438 - val_loss: 0.4017
# Epoch 46/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 14s 453ms/step - accuracy: 0.7500 - loss: 0.5752 - val_accuracy: 0.8375 - val_loss: 0.4063
# Epoch 47/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 96s 4s/step - accuracy: 0.8506 - loss: 0.4364 - val_accuracy: 0.8562 - val_loss: 0.3742
# Epoch 48/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 13s 443ms/step - accuracy: 0.8750 - loss: 0.2834 - val_accuracy: 0.8625 - val_loss: 0.3573
# Epoch 49/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 97s 4s/step - accuracy: 0.8164 - loss: 0.4586 - val_accuracy: 0.8562 - val_loss: 0.3749
# Epoch 50/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 14s 446ms/step - accuracy: 0.8438 - loss: 0.5317 - val_accuracy: 0.8625 - val_loss: 0.3707
# Epoch 51/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 97s 4s/step - accuracy: 0.8189 - loss: 0.4713 - val_accuracy: 0.8375 - val_loss: 0.4141
# Epoch 52/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 14s 450ms/step - accuracy: 0.8438 - loss: 0.4643 - val_accuracy: 0.8375 - val_loss: 0.4005
# Epoch 53/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 97s 4s/step - accuracy: 0.8249 - loss: 0.4798 - val_accuracy: 0.8375 - val_loss: 0.4171
# Epoch 54/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 13s 442ms/step - accuracy: 0.9062 - loss: 0.2861 - val_accuracy: 0.8438 - val_loss: 0.4130
# Epoch 55/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 97s 4s/step - accuracy: 0.8382 - loss: 0.4187 - val_accuracy: 0.8562 - val_loss: 0.3591
# Epoch 56/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 14s 446ms/step - accuracy: 0.6562 - loss: 0.8217 - val_accuracy: 0.8562 - val_loss: 0.3604
# Epoch 57/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 97s 4s/step - accuracy: 0.8361 - loss: 0.4193 - val_accuracy: 0.8438 - val_loss: 0.3624
# Epoch 58/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 14s 453ms/step - accuracy: 0.9062 - loss: 0.1781 - val_accuracy: 0.8375 - val_loss: 0.3577
# Epoch 59/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 97s 4s/step - accuracy: 0.8148 - loss: 0.4263 - val_accuracy: 0.8188 - val_loss: 0.4010
# Epoch 60/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 13s 444ms/step - accuracy: 0.7188 - loss: 0.5862 - val_accuracy: 0.8250 - val_loss: 0.3996
# Epoch 61/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 97s 4s/step - accuracy: 0.8149 - loss: 0.4598 - val_accuracy: 0.8250 - val_loss: 0.4138
# Epoch 62/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 13s 444ms/step - accuracy: 0.8125 - loss: 0.3910 - val_accuracy: 0.8313 - val_loss: 0.4057
# Epoch 63/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 96s 4s/step - accuracy: 0.8425 - loss: 0.4226 - val_accuracy: 0.8438 - val_loss: 0.4150
# Epoch 64/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 14s 453ms/step - accuracy: 0.9375 - loss: 0.2667 - val_accuracy: 0.8313 - val_loss: 0.4250
# Epoch 65/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 96s 4s/step - accuracy: 0.8188 - loss: 0.4548 - val_accuracy: 0.8313 - val_loss: 0.3808
# Epoch 66/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 13s 442ms/step - accuracy: 0.8750 - loss: 0.5645 - val_accuracy: 0.8188 - val_loss: 0.3817
# Epoch 67/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 98s 4s/step - accuracy: 0.8331 - loss: 0.4218 - val_accuracy: 0.8500 - val_loss: 0.3730
# Epoch 68/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 14s 467ms/step - accuracy: 0.7812 - loss: 0.4635 - val_accuracy: 0.8438 - val_loss: 0.3855
# Epoch 69/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 97s 4s/step - accuracy: 0.8362 - loss: 0.4085 - val_accuracy: 0.8188 - val_loss: 0.4525
# Epoch 70/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 14s 459ms/step - accuracy: 0.7188 - loss: 0.6865 - val_accuracy: 0.8250 - val_loss: 0.4339
# Epoch 71/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 96s 4s/step - accuracy: 0.8356 - loss: 0.4648 - val_accuracy: 0.8125 - val_loss: 0.4268
# Epoch 72/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 14s 466ms/step - accuracy: 0.8125 - loss: 0.4697 - val_accuracy: 0.8188 - val_loss: 0.4225
# Epoch 73/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 101s 4s/step - accuracy: 0.8595 - loss: 0.4365 - val_accuracy: 0.8500 - val_loss: 0.3580
# Epoch 74/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 14s 467ms/step - accuracy: 0.8750 - loss: 0.4574 - val_accuracy: 0.8500 - val_loss: 0.3490
# Epoch 75/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 98s 4s/step - accuracy: 0.8280 - loss: 0.4651 - val_accuracy: 0.8313 - val_loss: 0.4005
# Epoch 76/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 13s 437ms/step - accuracy: 0.9688 - loss: 0.1962 - val_accuracy: 0.8188 - val_loss: 0.4272
# Epoch 77/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 96s 4s/step - accuracy: 0.8453 - loss: 0.4079 - val_accuracy: 0.8687 - val_loss: 0.3435
# Epoch 78/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 13s 440ms/step - accuracy: 0.8125 - loss: 0.3467 - val_accuracy: 0.8562 - val_loss: 0.3664
# Epoch 79/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 97s 4s/step - accuracy: 0.8651 - loss: 0.3969 - val_accuracy: 0.8375 - val_loss: 0.3813
# Epoch 80/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 13s 446ms/step - accuracy: 0.6875 - loss: 0.8123 - val_accuracy: 0.8313 - val_loss: 0.4161
# Epoch 81/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 96s 4s/step - accuracy: 0.8094 - loss: 0.5269 - val_accuracy: 0.8625 - val_loss: 0.3510
# Epoch 82/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 13s 444ms/step - accuracy: 0.8750 - loss: 0.4501 - val_accuracy: 0.8562 - val_loss: 0.3688
# Epoch 83/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 97s 4s/step - accuracy: 0.8395 - loss: 0.4383 - val_accuracy: 0.8062 - val_loss: 0.4834
# Epoch 84/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 13s 437ms/step - accuracy: 0.8750 - loss: 0.3794 - val_accuracy: 0.8125 - val_loss: 0.4969
# Epoch 85/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 96s 4s/step - accuracy: 0.8226 - loss: 0.4789 - val_accuracy: 0.8687 - val_loss: 0.3225
# Epoch 86/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 14s 458ms/step - accuracy: 0.8438 - loss: 0.4316 - val_accuracy: 0.8438 - val_loss: 0.3570
# Epoch 87/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 96s 4s/step - accuracy: 0.8274 - loss: 0.4509 - val_accuracy: 0.8687 - val_loss: 0.3824
# Epoch 88/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 13s 442ms/step - accuracy: 0.7500 - loss: 0.6536 - val_accuracy: 0.8750 - val_loss: 0.3654
# Epoch 89/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 96s 4s/step - accuracy: 0.8503 - loss: 0.3933 - val_accuracy: 0.8500 - val_loss: 0.3987
# Epoch 90/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 14s 456ms/step - accuracy: 0.9062 - loss: 0.2358 - val_accuracy: 0.8500 - val_loss: 0.3972
# Epoch 91/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 96s 4s/step - accuracy: 0.8640 - loss: 0.3585 - val_accuracy: 0.8500 - val_loss: 0.3687
# Epoch 92/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 13s 446ms/step - accuracy: 0.8125 - loss: 0.3506 - val_accuracy: 0.8438 - val_loss: 0.3716
# Epoch 93/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 96s 4s/step - accuracy: 0.8169 - loss: 0.4794 - val_accuracy: 0.8313 - val_loss: 0.4408
# Epoch 94/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 13s 444ms/step - accuracy: 0.8438 - loss: 0.4330 - val_accuracy: 0.8313 - val_loss: 0.4384
# Epoch 95/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 96s 4s/step - accuracy: 0.8572 - loss: 0.4322 - val_accuracy: 0.8250 - val_loss: 0.4079
# Epoch 96/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 13s 439ms/step - accuracy: 0.8438 - loss: 0.4990 - val_accuracy: 0.8313 - val_loss: 0.3932
# Epoch 97/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 96s 4s/step - accuracy: 0.8410 - loss: 0.4344 - val_accuracy: 0.8250 - val_loss: 0.3735
# Epoch 98/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 14s 452ms/step - accuracy: 0.8438 - loss: 0.3829 - val_accuracy: 0.8438 - val_loss: 0.3555
# Epoch 99/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 96s 4s/step - accuracy: 0.7998 - loss: 0.4758 - val_accuracy: 0.8438 - val_loss: 0.3898
# Epoch 100/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 13s 438ms/step - accuracy: 1.0000 - loss: 0.2030 - val_accuracy: 0.8313 - val_loss: 0.3971
# Epoch 101/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 96s 4s/step - accuracy: 0.8375 - loss: 0.4225 - val_accuracy: 0.8500 - val_loss: 0.3593
# Epoch 102/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 13s 437ms/step - accuracy: 0.9062 - loss: 0.3010 - val_accuracy: 0.8500 - val_loss: 0.3572
# Epoch 103/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 96s 4s/step - accuracy: 0.8530 - loss: 0.4087 - val_accuracy: 0.8375 - val_loss: 0.3766
# Epoch 104/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 13s 441ms/step - accuracy: 0.6562 - loss: 0.6537 - val_accuracy: 0.8438 - val_loss: 0.3917
# Epoch 105/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 96s 4s/step - accuracy: 0.8316 - loss: 0.4409 - val_accuracy: 0.8375 - val_loss: 0.4033
# Epoch 106/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 13s 439ms/step - accuracy: 0.8438 - loss: 0.2758 - val_accuracy: 0.8375 - val_loss: 0.3979
# Epoch 107/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 97s 4s/step - accuracy: 0.8413 - loss: 0.3987 - val_accuracy: 0.8687 - val_loss: 0.3495
# Epoch 108/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 13s 448ms/step - accuracy: 0.8438 - loss: 0.3195 - val_accuracy: 0.8625 - val_loss: 0.3728
# Epoch 109/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 96s 4s/step - accuracy: 0.8538 - loss: 0.4247 - val_accuracy: 0.8250 - val_loss: 0.4450
# Epoch 110/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 13s 444ms/step - accuracy: 0.7500 - loss: 0.8027 - val_accuracy: 0.8500 - val_loss: 0.4144
# Epoch 111/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 97s 4s/step - accuracy: 0.8300 - loss: 0.4445 - val_accuracy: 0.8125 - val_loss: 0.4374
# Epoch 112/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 13s 437ms/step - accuracy: 0.8438 - loss: 0.5397 - val_accuracy: 0.8375 - val_loss: 0.4258
# Epoch 113/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 96s 4s/step - accuracy: 0.8505 - loss: 0.4223 - val_accuracy: 0.8438 - val_loss: 0.3668
# Epoch 114/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 13s 439ms/step - accuracy: 0.8125 - loss: 0.4902 - val_accuracy: 0.8562 - val_loss: 0.3523
# Epoch 115/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 96s 4s/step - accuracy: 0.8312 - loss: 0.4118 - val_accuracy: 0.8750 - val_loss: 0.3281
# Epoch 116/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 14s 451ms/step - accuracy: 0.8438 - loss: 0.3445 - val_accuracy: 0.8750 - val_loss: 0.3282
# Epoch 117/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 97s 4s/step - accuracy: 0.8256 - loss: 0.4496 - val_accuracy: 0.8375 - val_loss: 0.3764
# Epoch 118/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 13s 439ms/step - accuracy: 0.7812 - loss: 0.3521 - val_accuracy: 0.8250 - val_loss: 0.4305
# Epoch 119/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 95s 4s/step - accuracy: 0.8244 - loss: 0.4955 - val_accuracy: 0.8500 - val_loss: 0.3325
# Epoch 120/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 14s 459ms/step - accuracy: 0.9688 - loss: 0.3075 - val_accuracy: 0.8562 - val_loss: 0.3377
# Epoch 121/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 96s 4s/step - accuracy: 0.8528 - loss: 0.3883 - val_accuracy: 0.8250 - val_loss: 0.4223
# Epoch 122/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 13s 439ms/step - accuracy: 0.8750 - loss: 0.2285 - val_accuracy: 0.8313 - val_loss: 0.4399
# Epoch 123/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 97s 4s/step - accuracy: 0.8448 - loss: 0.4410 - val_accuracy: 0.8375 - val_loss: 0.4284
# Epoch 124/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 13s 439ms/step - accuracy: 0.9062 - loss: 0.4852 - val_accuracy: 0.8375 - val_loss: 0.4418
# Epoch 125/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 96s 4s/step - accuracy: 0.8266 - loss: 0.3992 - val_accuracy: 0.8750 - val_loss: 0.3143
# Epoch 126/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 13s 443ms/step - accuracy: 0.9375 - loss: 0.1745 - val_accuracy: 0.8750 - val_loss: 0.3145
# Epoch 127/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 96s 4s/step - accuracy: 0.8510 - loss: 0.4912 - val_accuracy: 0.8625 - val_loss: 0.3692
# Epoch 128/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 13s 442ms/step - accuracy: 0.8438 - loss: 0.4637 - val_accuracy: 0.8625 - val_loss: 0.3710
# Epoch 129/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 96s 4s/step - accuracy: 0.8409 - loss: 0.4350 - val_accuracy: 0.8125 - val_loss: 0.4636
# Epoch 130/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 13s 442ms/step - accuracy: 0.9062 - loss: 0.2528 - val_accuracy: 0.8062 - val_loss: 0.4796
# Epoch 131/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 96s 4s/step - accuracy: 0.8362 - loss: 0.4504 - val_accuracy: 0.8438 - val_loss: 0.4264
# Epoch 132/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 14s 451ms/step - accuracy: 0.8438 - loss: 0.5078 - val_accuracy: 0.8438 - val_loss: 0.4325
# Epoch 133/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 96s 4s/step - accuracy: 0.8272 - loss: 0.4062 - val_accuracy: 0.8750 - val_loss: 0.3474
# Epoch 134/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 13s 435ms/step - accuracy: 0.8750 - loss: 0.3894 - val_accuracy: 0.8687 - val_loss: 0.3512
# Epoch 135/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 96s 4s/step - accuracy: 0.8609 - loss: 0.3719 - val_accuracy: 0.8375 - val_loss: 0.3961
# Epoch 136/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 13s 436ms/step - accuracy: 0.9688 - loss: 0.1957 - val_accuracy: 0.8375 - val_loss: 0.4014
# Epoch 137/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 96s 4s/step - accuracy: 0.8541 - loss: 0.3904 - val_accuracy: 0.8750 - val_loss: 0.3357
# Epoch 138/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 14s 450ms/step - accuracy: 0.7500 - loss: 0.4816 - val_accuracy: 0.8750 - val_loss: 0.3354
# Epoch 139/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 96s 4s/step - accuracy: 0.8254 - loss: 0.4336 - val_accuracy: 0.8562 - val_loss: 0.3573
# Epoch 140/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 13s 450ms/step - accuracy: 0.7812 - loss: 0.5334 - val_accuracy: 0.8562 - val_loss: 0.3642
# Epoch 141/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 97s 4s/step - accuracy: 0.8293 - loss: 0.4191 - val_accuracy: 0.8313 - val_loss: 0.4095
# Epoch 142/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 13s 442ms/step - accuracy: 0.8125 - loss: 0.5226 - val_accuracy: 0.8250 - val_loss: 0.4476
# Epoch 143/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 97s 4s/step - accuracy: 0.8306 - loss: 0.4129 - val_accuracy: 0.8750 - val_loss: 0.3453
# Epoch 144/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 14s 450ms/step - accuracy: 0.8125 - loss: 0.4733 - val_accuracy: 0.8687 - val_loss: 0.3582
# Epoch 145/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 96s 4s/step - accuracy: 0.8302 - loss: 0.4723 - val_accuracy: 0.8813 - val_loss: 0.3237
# Epoch 146/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 13s 441ms/step - accuracy: 0.8125 - loss: 0.3881 - val_accuracy: 0.8625 - val_loss: 0.3476
# Epoch 147/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 96s 4s/step - accuracy: 0.8580 - loss: 0.3880 - val_accuracy: 0.8750 - val_loss: 0.3599
# Epoch 148/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 13s 437ms/step - accuracy: 0.7812 - loss: 0.5447 - val_accuracy: 0.8813 - val_loss: 0.3672
# Epoch 149/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 96s 4s/step - accuracy: 0.8548 - loss: 0.4272 - val_accuracy: 0.8188 - val_loss: 0.5448
# Epoch 150/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 13s 446ms/step - accuracy: 0.8750 - loss: 0.2828 - val_accuracy: 0.8188 - val_loss: 0.5455
# Epoch 151/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 95s 4s/step - accuracy: 0.8486 - loss: 0.4161 - val_accuracy: 0.8438 - val_loss: 0.3753
# Epoch 152/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 13s 427ms/step - accuracy: 0.9062 - loss: 0.4531 - val_accuracy: 0.8687 - val_loss: 0.3516
# Epoch 153/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 94s 4s/step - accuracy: 0.8247 - loss: 0.4514 - val_accuracy: 0.8625 - val_loss: 0.3490
# Epoch 154/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 13s 426ms/step - accuracy: 0.9062 - loss: 0.3313 - val_accuracy: 0.8625 - val_loss: 0.3428
# Epoch 155/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 94s 4s/step - accuracy: 0.8359 - loss: 0.4268 - val_accuracy: 0.8625 - val_loss: 0.3665
# Epoch 156/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 13s 439ms/step - accuracy: 0.7812 - loss: 0.4233 - val_accuracy: 0.8750 - val_loss: 0.3434
# Epoch 157/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 95s 4s/step - accuracy: 0.8343 - loss: 0.3730 - val_accuracy: 0.8375 - val_loss: 0.4459
# Epoch 158/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 13s 430ms/step - accuracy: 0.9375 - loss: 0.2346 - val_accuracy: 0.8250 - val_loss: 0.4635
# Epoch 159/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 94s 4s/step - accuracy: 0.8505 - loss: 0.3749 - val_accuracy: 0.8500 - val_loss: 0.3879
# Epoch 160/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 13s 434ms/step - accuracy: 0.9375 - loss: 0.2127 - val_accuracy: 0.8625 - val_loss: 0.3701
# Epoch 161/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 94s 4s/step - accuracy: 0.8520 - loss: 0.4333 - val_accuracy: 0.8562 - val_loss: 0.3692
# Epoch 162/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 13s 436ms/step - accuracy: 0.8438 - loss: 0.2738 - val_accuracy: 0.8562 - val_loss: 0.3688
# Epoch 163/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 94s 4s/step - accuracy: 0.8500 - loss: 0.3883 - val_accuracy: 0.8438 - val_loss: 0.4357
# Epoch 164/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 13s 429ms/step - accuracy: 0.8438 - loss: 0.4374 - val_accuracy: 0.8438 - val_loss: 0.4183
# Epoch 165/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 95s 4s/step - accuracy: 0.8296 - loss: 0.4404 - val_accuracy: 0.8562 - val_loss: 0.3639
# Epoch 166/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 13s 425ms/step - accuracy: 0.8750 - loss: 0.3557 - val_accuracy: 0.8625 - val_loss: 0.3461
# Epoch 167/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 94s 4s/step - accuracy: 0.8448 - loss: 0.4106 - val_accuracy: 0.8562 - val_loss: 0.4011
# Epoch 168/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 13s 439ms/step - accuracy: 0.8125 - loss: 0.3302 - val_accuracy: 0.8625 - val_loss: 0.3838
# Epoch 169/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 95s 4s/step - accuracy: 0.8543 - loss: 0.4451 - val_accuracy: 0.8438 - val_loss: 0.4266
# Epoch 170/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 13s 430ms/step - accuracy: 0.9677 - loss: 0.1656 - val_accuracy: 0.8500 - val_loss: 0.4236
# Epoch 171/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 95s 4s/step - accuracy: 0.8515 - loss: 0.4220 - val_accuracy: 0.8687 - val_loss: 0.3395
# Epoch 172/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 13s 429ms/step - accuracy: 0.7188 - loss: 0.6288 - val_accuracy: 0.8687 - val_loss: 0.3462
# Epoch 173/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 95s 4s/step - accuracy: 0.8517 - loss: 0.3765 - val_accuracy: 0.8313 - val_loss: 0.4563
# Epoch 174/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 13s 433ms/step - accuracy: 0.8438 - loss: 0.3886 - val_accuracy: 0.8438 - val_loss: 0.4251
# Epoch 175/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 95s 4s/step - accuracy: 0.8367 - loss: 0.4219 - val_accuracy: 0.8500 - val_loss: 0.3963
# Epoch 176/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 13s 432ms/step - accuracy: 0.9375 - loss: 0.1879 - val_accuracy: 0.8500 - val_loss: 0.3994
# Epoch 177/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 95s 4s/step - accuracy: 0.8531 - loss: 0.3981 - val_accuracy: 0.8313 - val_loss: 0.4163
# Epoch 178/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 13s 432ms/step - accuracy: 0.8750 - loss: 0.3521 - val_accuracy: 0.8313 - val_loss: 0.4018
# Epoch 179/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 94s 4s/step - accuracy: 0.8551 - loss: 0.3789 - val_accuracy: 0.8438 - val_loss: 0.3799
# Epoch 180/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 13s 433ms/step - accuracy: 0.8438 - loss: 0.4075 - val_accuracy: 0.8500 - val_loss: 0.3660
# Epoch 181/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 95s 4s/step - accuracy: 0.8486 - loss: 0.3634 - val_accuracy: 0.8687 - val_loss: 0.3252
# Epoch 182/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 13s 440ms/step - accuracy: 0.8438 - loss: 0.2492 - val_accuracy: 0.8687 - val_loss: 0.3264
# Epoch 183/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 95s 4s/step - accuracy: 0.8475 - loss: 0.4211 - val_accuracy: 0.8687 - val_loss: 0.3630
# Epoch 184/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 13s 434ms/step - accuracy: 0.7188 - loss: 0.8228 - val_accuracy: 0.8687 - val_loss: 0.3497
# Epoch 185/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 95s 4s/step - accuracy: 0.8574 - loss: 0.4076 - val_accuracy: 0.8687 - val_loss: 0.3285
# Epoch 186/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 13s 431ms/step - accuracy: 0.8710 - loss: 0.3460 - val_accuracy: 0.8625 - val_loss: 0.3370
# Epoch 187/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 95s 4s/step - accuracy: 0.8427 - loss: 0.3931 - val_accuracy: 0.8687 - val_loss: 0.3372
# Epoch 188/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 14s 451ms/step - accuracy: 0.9375 - loss: 0.2101 - val_accuracy: 0.8750 - val_loss: 0.3288
# Epoch 189/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 96s 4s/step - accuracy: 0.8302 - loss: 0.4456 - val_accuracy: 0.8750 - val_loss: 0.3086
# Epoch 190/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 13s 434ms/step - accuracy: 0.8750 - loss: 0.3039 - val_accuracy: 0.8875 - val_loss: 0.2933
# Epoch 191/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 97s 4s/step - accuracy: 0.8540 - loss: 0.3606 - val_accuracy: 0.8750 - val_loss: 0.3340
# Epoch 192/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 14s 452ms/step - accuracy: 0.8125 - loss: 0.4019 - val_accuracy: 0.8750 - val_loss: 0.3348
# Epoch 193/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 96s 4s/step - accuracy: 0.8579 - loss: 0.3627 - val_accuracy: 0.8438 - val_loss: 0.3886
# Epoch 194/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 13s 442ms/step - accuracy: 0.8125 - loss: 0.3538 - val_accuracy: 0.8438 - val_loss: 0.3883
# Epoch 195/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 96s 4s/step - accuracy: 0.8495 - loss: 0.3701 - val_accuracy: 0.8625 - val_loss: 0.3267
# Epoch 196/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 13s 440ms/step - accuracy: 0.8438 - loss: 0.3743 - val_accuracy: 0.8625 - val_loss: 0.3296
# Epoch 197/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 95s 4s/step - accuracy: 0.8528 - loss: 0.3579 - val_accuracy: 0.8375 - val_loss: 0.4132
# Epoch 198/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 13s 439ms/step - accuracy: 0.7812 - loss: 0.4901 - val_accuracy: 0.8375 - val_loss: 0.4116
# Epoch 199/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 96s 4s/step - accuracy: 0.8462 - loss: 0.3858 - val_accuracy: 0.8687 - val_loss: 0.3463
# Epoch 200/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 13s 438ms/step - accuracy: 0.8125 - loss: 0.3772 - val_accuracy: 0.8687 - val_loss: 0.3495

# %%
import matplotlib.pyplot as plt

# Plot the accuracy
def plot_accuracy(history):
    plt.figure(figsize=(10, 5))  # Optional: Set figure size for better visualization
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    if 'val_accuracy' in history.history: # Check if validation accuracy exists
        plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Model Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(loc='upper left')
    plt.grid()  # Optional: Add grid for better readability
    plt.show()

# Plot the loss
def plot_loss(history):
    plt.figure(figsize=(10, 5))  # Optional: Set figure size for better visualization
    plt.plot(history.history['loss'], label='Train Loss')
    if 'val_loss' in history.history:  # Check if validation loss exists
        plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Model Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(loc='upper left')
    plt.grid()  # Optional: Add grid for better readability
    plt.show()

# Call the plot functions
plot_accuracy(history)
plot_loss(history)

# %%
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import numpy as np
import matplotlib.pyplot as plt



# Path to the image you want to predict
image_path = r"C:\Users\DELL 5540\Desktop\AI-Diagnostics-for-Predicting-Bone-Metastasis-in-Lung-Cancer-Patients-main\archive\The IQ-OTHNCCD lung cancer dataset\The IQ-OTHNCCD lung cancer dataset\test\Normal cases\Normal case (1).jpg"

# Step 1: Load the image
img = load_img(image_path, target_size=(224, 224))  # Resize to match input shape
plt.imshow(img)  # Display the image
plt.axis('off')  # Hide axis
plt.show()

# Step 2: Preprocess the image
img_array = img_to_array(img)  # Convert image to array
img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension
img_array /= 255.0  # Rescale pixel values

# Step 3: Make a prediction
predictions = model.predict(img_array)

# Step 4: Interpret the prediction
class_indices = {0: 'normal', 1: 'malignant', 2: 'benign'}  # Update according to your dataset's class indices
predicted_class = np.argmax(predictions, axis=1)  # Get the index of the highest score

# Display the result
print(f"Predicted class: {class_indices[predicted_class[0]]}")
print(f"Prediction confidence: {np.max(predictions) * 100:.2f}%")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 22
#      19 img_array /= 255.0  # Rescale pixel values
#      21 # Step 3: Make a prediction
# ---> 22 predictions = model.predict(img_array)
#      24 # Step 4: Interpret the prediction
#      25 class_indices = {0: 'normal', 1: 'malignant', 2: 'benign'}  # Update according to your dataset's class indices
#
# File ~\AppData\Roaming\Python\Python311\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\input_spec.py:245, in assert_input_compatibility(input_spec, inputs, layer_name)
#     243 if spec_dim is not None and dim is not None:
#     244     if spec_dim != dim:
# --> 245         raise ValueError(
#     246             f'Input {input_index} of layer "{layer_name}" is '
#     247             "incompatible with the layer: "
#     248             f"expected shape={spec.shape}, "
#     249             f"found shape={shape}"
#     250         )
#
# ValueError: Input 0 of layer "functional" is incompatible with the layer: expected shape=(None, 299, 299, 3), found shape=(1, 224, 224, 3)

# %%
image_path = r"C:\Users\DELL 5540\Desktop\AI-Diagnostics-for-Predicting-Bone-Metastasis-in-Lung-Cancer-Patients-main\archive\The IQ-OTHNCCD lung cancer dataset\The IQ-OTHNCCD lung cancer dataset\test\Malignant cases\Malignant case (1).jpg"

# Step 1: Load the image
img = load_img(image_path, target_size=(224, 224))  # Resize to match input shape
plt.imshow(img)  # Display the image
plt.axis('off')  # Hide axis
plt.show()

# Step 2: Preprocess the image
img_array = img_to_array(img)  # Convert image to array
img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension
img_array /= 255.0  # Rescale pixel values

# Step 3: Make a prediction
predictions = model.predict(img_array)

# Step 4: Interpret the prediction
class_indices = {0: 'normal', 1: 'malignant', 2: 'benign'}  # Update according to your dataset's class indices
predicted_class = np.argmax(predictions, axis=1)  # Get the index of the highest score

# Display the result
print(f"Predicted class: {class_indices[predicted_class[0]]}")
print(f"Prediction confidence: {np.max(predictions) * 100:.2f}%")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 15
#      12 img_array /= 255.0  # Rescale pixel values
#      14 # Step 3: Make a prediction
# ---> 15 predictions = model.predict(img_array)
#      17 # Step 4: Interpret the prediction
#      18 class_indices = {0: 'normal', 1: 'malignant', 2: 'benign'}  # Update according to your dataset's class indices
#
# File ~\AppData\Roaming\Python\Python311\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\input_spec.py:245, in assert_input_compatibility(input_spec, inputs, layer_name)
#     243 if spec_dim is not None and dim is not None:
#     244     if spec_dim != dim:
# --> 245         raise ValueError(
#     246             f'Input {input_index} of layer "{layer_name}" is '
#     247             "incompatible with the layer: "
#     248             f"expected shape={spec.shape}, "
#     249             f"found shape={shape}"
#     250         )
#
# ValueError: Input 0 of layer "functional" is incompatible with the layer: expected shape=(None, 299, 299, 3), found shape=(1, 224, 224, 3)

# %%
image_path = r"C:\Users\DELL 5540\Desktop\AI-Diagnostics-for-Predicting-Bone-Metastasis-in-Lung-Cancer-Patients-main\archive\The IQ-OTHNCCD lung cancer dataset\The IQ-OTHNCCD lung cancer dataset\test\Bengin cases\Bengin case (1).jpg"
# Step 1: Load the image
img = load_img(image_path, target_size=(224, 224))  # Resize to match input shape
plt.imshow(img)  # Display the image
plt.axis('off')  # Hide axis
plt.show()

# Step 2: Preprocess the image
img_array = img_to_array(img)  # Convert image to array
img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension
img_array /= 255.0  # Rescale pixel values

# Step 3: Make a prediction
predictions = model.predict(img_array)

# Step 4: Interpret the prediction
class_indices = {0: 'normal', 1: 'malignant', 2: 'benign'}  # Update according to your dataset's class indices
predicted_class = np.argmax(predictions, axis=1)  # Get the index of the highest score

# Display the result
print(f"Predicted class: {class_indices[predicted_class[0]]}")
print(f"Prediction confidence: {np.max(predictions) * 100:.2f}%")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 14
#      11 img_array /= 255.0  # Rescale pixel values
#      13 # Step 3: Make a prediction
# ---> 14 predictions = model.predict(img_array)
#      16 # Step 4: Interpret the prediction
#      17 class_indices = {0: 'normal', 1: 'malignant', 2: 'benign'}  # Update according to your dataset's class indices
#
# File ~\AppData\Roaming\Python\Python311\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\input_spec.py:245, in assert_input_compatibility(input_spec, inputs, layer_name)
#     243 if spec_dim is not None and dim is not None:
#     244     if spec_dim != dim:
# --> 245         raise ValueError(
#     246             f'Input {input_index} of layer "{layer_name}" is '
#     247             "incompatible with the layer: "
#     248             f"expected shape={spec.shape}, "
#     249             f"found shape={shape}"
#     250         )
#
# ValueError: Input 0 of layer "functional" is incompatible with the layer: expected shape=(None, 299, 299, 3), found shape=(1, 224, 224, 3)

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

# Predict on the test set
test_pred = model.predict(test_generator, steps=test_generator.samples // test_generator.batch_size + 1)
test_pred_classes = np.argmax(test_pred, axis=1)

# Get true labels
true_classes = test_generator.classes

# Ensure sizes match
print(f"True labels: {len(true_classes)}, Predictions: {len(test_pred_classes)}")

# Confusion Matrix
cm = confusion_matrix(true_classes, test_pred_classes)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=test_generator.class_indices.keys(), 
            yticklabels=test_generator.class_indices.keys())
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# Classification Report
print(classification_report(true_classes, test_pred_classes, target_names=list(test_generator.class_indices.keys())))
# Out:
# C:\Users\DELL 5540\AppData\Roaming\Python\Python311\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step
# True labels: 166, Predictions: 166
#                  precision    recall  f1-score   support
#
#    Bengin cases       0.00      0.00      0.00        18
# Malignant cases       0.50      0.49      0.50        85
#    Normal cases       0.39      0.51      0.44        63
#
#        accuracy                           0.45       166
#       macro avg       0.30      0.33      0.31       166
#    weighted avg       0.40      0.45      0.42       166
# c:\Program Files\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Program Files\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Program Files\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
